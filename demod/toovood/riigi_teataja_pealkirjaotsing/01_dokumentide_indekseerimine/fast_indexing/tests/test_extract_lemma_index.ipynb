# %%
import sys
sys.path.append('../../')

# %%
from estnltk import Text
from pandas import DataFrame

from fast_indexing.fast_indexing import extract_lemma_index
from estnltk_patches.rt_text_analyzer import RTTextAnalyzer

# %%
RT_ANALYZER = RTTextAnalyzer()
RTP_ANALYZER = RTTextAnalyzer(propername=True)

# %%
text = Text('kala')
RT_ANALYZER(text)
result = DataFrame(extract_lemma_index('42', text), columns = ['wordform', 'doc_id', 'start', 'end', 'weight', 'is_subword'])
display(result)
# Out:
#   wordform doc_id  start  end  weight  is_subword
# 0     kala     42      0    4     1.0       False

# %%
text = Text('sadama')
RT_ANALYZER(text)
result = DataFrame(extract_lemma_index('42', text), columns = ['wordform', 'doc_id', 'start', 'end', 'weight', 'is_subword'])
display(result)
# Out:
#   wordform doc_id  start  end  weight  is_subword
# 0   sadama     42      0    6     0.5       False
# 1    sadam     42      0    6     0.5       False

# %%
text = Text('kalamees')
RT_ANALYZER(text)
result = DataFrame(extract_lemma_index('42', text), columns = ['wordform', 'doc_id', 'start', 'end', 'weight', 'is_subword'])
display(result)
# Out:
#    wordform doc_id  start  end  weight  is_subword
# 0  kalamees     42      0    8     1.0       False
# 1      kala     42      0    8     1.0        True
# 2      mesi     42      0    8     0.5        True
# 3      mees     42      0    8     0.5        True

# %%
text = Text('Punameremao pisarad.')
RT_ANALYZER(text)
result = DataFrame(extract_lemma_index('42', text), columns = ['wordform', 'doc_id', 'start', 'end', 'weight', 'is_subword'])
display(result)
# Out:
#        wordform doc_id  start  end  weight  is_subword
# 0  punameremagu     42      0   11     0.5       False
# 1  punameremadu     42      0   11     0.5       False
# 2          puna     42      0   11     0.5        True
# 3        punama     42      0   11     0.5        True
# 4          meri     42      0   11     1.0        True
# 5          magu     42      0   11     0.5        True
# 6          madu     42      0   11     0.5        True
# 7         pisar     42     12   19     1.0       False

# %%
text = Text('Töökorraseadus')
RTP_ANALYZER(text)
result = DataFrame(extract_lemma_index('42', text), columns = ['wordform', 'doc_id', 'start', 'end', 'weight', 'is_subword'])
display(result)
# Out:
#          wordform doc_id  start  end  weight  is_subword
# 0  töökorraseadus     42      0   14     0.5       False
# 1  Töökorraseadus     42      0   14     0.5       False
# 2             töö     42      0   14     0.5        True
# 3            kord     42      0   14     0.5        True
# 4         seaduma     42      0   14     0.5        True
# 5          seadus     42      0   14     0.5        True
# 6         töökord     42      0   14     0.5        True

# %%
text = Text('Töökorraseadus')
RTP_ANALYZER(text)
result = DataFrame(extract_lemma_index('42', text, ignore_pos=['H']), columns = ['wordform', 'doc_id', 'start', 'end', 'weight', 'is_subword'])
display(result)
# Out:
#          wordform doc_id  start  end  weight  is_subword
# 0  töökorraseadus     42      0   14     1.0       False
# 1             töö     42      0   14     1.0        True
# 2            kord     42      0   14     1.0        True
# 3         seaduma     42      0   14     0.5        True
# 4          seadus     42      0   14     0.5        True
